# %% [markdown]
# # Auto Notebook
# This was generated and executed programmatically.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 6.28, 300)
y = np.sin(x)
plt.plot(x, y)
plt.title('Sine')
plt.savefig('nb_plot.png', dpi=120)
print('sum(y)=', y.sum())
# Out:
# sum(y)= -0.0013511226898401674
